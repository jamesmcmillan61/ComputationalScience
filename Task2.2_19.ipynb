# %% [markdown]
# # Task 2.2
#
# If the simulation starts in the center (the grey shaded box), and when it reaches the steady-state value for the number of cells, the tumor moves to any one of the other eight cells of the grid. The choice of the cell to move to is random. When the growth moves to a second cell, your initial population of tumor cells is reset to the initial conditions, and you carry on stimulating the growth till a steady state is reached for two cells of the grid. Now the cell growth has to move another cell in the grid, and your choice of locations is now seven
#
# Plot the movement of the tumor cell growth through the grid. A suggestion is to start with a small grid (say 100X 100). While you are doing this, consider the issues associated with the numerical strategy you are employing. If the numerical methods are changed, what will be the change in the complexity of the simulation?

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
# Simulates a gompertz growth model within a sigular cell 
def CalculateGroath(N0, k, M, t_max, h):
    t = np.arange(0, t_max, h)
    N = np.zeros_like(t)
    # Sets the first value - 10^9
    N[0] = N0
    

    
    for i in range(1, len(t)):
        N[i] = N[i-1] + h * k * N[i-1] * np.log(M / N[i-1])
    
    return t, N

# %%
def time_to_reach_Steady(N, t, fraction):
    target = fraction * N[-1]
    for i in range(len(N)):
        if N[i] >= target:
            return t[i]
    return None

# %%
# Parameters
#k = 0.006
#N0 = 10**9
#h = 0.001
#t_max = 1500
#fractions = [0.66]
#M = 10**13

# %%
# Creates a 2d with all the spaces in the grid - once a cell gets filled it will then be moved into an array called Visited_cells 
grid_size = 20
initial_cells = [(grid_size//2, grid_size//2)]
grid = np.zeros((grid_size, grid_size))
unvisited_cells = set((i, j) for i in range(grid_size) for j in range(grid_size))
unvisited_cells.discard((grid_size//2, grid_size//2))


# function to simulate the spread and then indvidualy the groath
def simulate_groth(grid, initial_cells, k, N0, M, h):
    visited_cells = initial_cells[:]
    
    while unvisited_cells:
        current_cell = visited_cells[-1]
        t, N = CalculateGroath(N0, k, M, t_max, h)
        
        grid[current_cell] = N[-1]
        
        # Plot grid
        plt.imshow(grid, cmap='hot', interpolation='nearest')
        plt.show()
        
        # Chooses which cell to move to next
        neighbors = [(current_cell[0] + i, current_cell[1] + j) for i in [-1, 0, 1] for j in [-1, 0, 1] if (i, j) != (0, 0)]
        # print ("neighbors are - ", neighbors)
        valid_moves = [cell for cell in neighbors if cell in unvisited_cells] # checks that their is a vallied cell for it to move into
        
        if not valid_moves:
            # if their are no moves left it will end the while loop 
            break
        
        next_cell = random.choice(valid_moves)
        unvisited_cells.discard(next_cell)
        visited_cells.append(next_cell)

    return grid

# %%
# Parameters
k = 0.006
N0 = 10**9
M = 10**13
h = 0.001
fractions = [0.66]
t_max = 1200

# %%
# Runs a pass based on the peramiter above, then displays 
t, N = CalculateGroath(N0, k, M, t_max, h)

plt.plot(t, N, label=f"M={M}")
for fraction in fractions:
    time_to_fraction = time_to_reach_Steady(N, t, fraction)
    print(f"Time to reach {fraction*100}% of M={M}: {time_to_fraction}")

plt.xlabel('Time')
plt.ylabel('Number of Cells')
plt.legend()
plt.show()




# Run sim
grid = simulate_groth(grid, initial_cells, k, N0, M, h)
# Out:
# Time to reach 66.0% of M=10000000000000: 513.695
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 18
#      12 plt.show()
#      17 # Run sim
# ---> 18 grid = simulate_groth(grid, initial_cells, k, N0, M, h)
#
# Cell In[77], line 15, in simulate_groth(grid, initial_cells, k, N0, M, h)
#      13 while unvisited_cells:
#      14     current_cell = visited_cells[-1]
# ---> 15     t, N = CalculateGroath(N0, k, M, t_max, h)
#      17     grid[current_cell] = N[-1]
#      19     # Plot grid
#
# Cell In[74], line 11, in CalculateGroath(N0, k, M, t_max, h)
#       6 N[0] = N0
#      10 for i in range(1, len(t)):
# ---> 11     N[i] = N[i-1] + h * k * N[i-1] * np.log(M / N[i-1])
#      13 return t, N
#
# KeyboardInterrupt:
